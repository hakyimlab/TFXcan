# %%
R.Version()$version.string
# Out:
# [1] "R version 3.6.0 (2019-04-26)"

# %%
install.packages('glmnet', dependencies = T)
# Out:
# Installing package into ‘/usr/lib64/R/library’
# (as ‘lib’ is unspecified)
# Warning message in install.packages("glmnet", dependencies = T):
# “'lib = "/usr/lib64/R/library"' is not writable”
# Error in install.packages("glmnet", dependencies = T): unable to install packages
# Traceback:
#
# 1. install.packages("glmnet", dependencies = T)
# 2. stop("unable to install packages")

# %%
`.libPaths`()
# Out:
# [1] "/usr/lib64/R/library" "/usr/share/R/library"

# %%
# Out:
#            Package    LibPath              Version  Priority
# assertthat assertthat /usr/lib64/R/library 0.2.1    NA
# backports  backports  /usr/lib64/R/library 1.1.4    NA
# base       base       /usr/lib64/R/library 3.6.0    base
# base64enc  base64enc  /usr/lib64/R/library 0.1-3    NA
# boot       boot       /usr/lib64/R/library 1.3-22   recommended
# class      class      /usr/lib64/R/library 7.3-15   recommended
# cli        cli        /usr/lib64/R/library 1.1.0    NA
# cluster    cluster    /usr/lib64/R/library 2.0.8    recommended
# codetools  codetools  /usr/lib64/R/library 0.2-16   recommended
# compiler   compiler   /usr/lib64/R/library 3.6.0    base
# crayon     crayon     /usr/lib64/R/library 1.3.4    NA
# datasets   datasets   /usr/lib64/R/library 3.6.0    base
# digest     digest     /usr/lib64/R/library 0.6.20   NA
# ellipsis   ellipsis   /usr/lib64/R/library 0.2.0.1  NA
# evaluate   evaluate   /usr/lib64/R/library 0.14     NA
# fansi      fansi      /usr/lib64/R/library 0.4.0    NA
# foreign    foreign    /usr/lib64/R/library 0.8-71   recommended
# glue       glue       /usr/lib64/R/library 1.3.1    NA
# graphics   graphics   /usr/lib64/R/library 3.6.0    base
# grDevices  grDevices  /usr/lib64/R/library 3.6.0    base
# grid       grid       /usr/lib64/R/library 3.6.0    base
# htmltools  htmltools  /usr/lib64/R/library 0.3.6    NA
# IRdisplay  IRdisplay  /usr/lib64/R/library 0.7.0    NA
# IRkernel   IRkernel   /usr/lib64/R/library 1.0.2    NA
# jsonlite   jsonlite   /usr/lib64/R/library 1.6      NA
# KernSmooth KernSmooth /usr/lib64/R/library 2.23-15  recommended
# lattice    lattice    /usr/lib64/R/library 0.20-38  recommended
# MASS       MASS       /usr/lib64/R/library 7.3-51.4 recommended
# Matrix     Matrix     /usr/lib64/R/library 1.2-17   recommended
# methods    methods    /usr/lib64/R/library 3.6.0    base
# mgcv       mgcv       /usr/lib64/R/library 1.8-28   recommended
# nlme       nlme       /usr/lib64/R/library 3.1-139  recommended
# nnet       nnet       /usr/lib64/R/library 7.3-12   recommended
# parallel   parallel   /usr/lib64/R/library 3.6.0    base
# pbdZMQ     pbdZMQ     /usr/lib64/R/library 0.3-3    NA
# pillar     pillar     /usr/lib64/R/library 1.4.2    NA
# Rcpp       Rcpp       /usr/lib64/R/library 1.0.1    NA
# repr       repr       /usr/lib64/R/library 1.0.1    NA
# rlang      rlang      /usr/lib64/R/library 0.4.0    NA
# rpart      rpart      /usr/lib64/R/library 4.1-15   recommended
# spatial    spatial    /usr/lib64/R/library 7.3-11   recommended
# splines    splines    /usr/lib64/R/library 3.6.0    base
# stats      stats      /usr/lib64/R/library 3.6.0    base
# stats4     stats4     /usr/lib64/R/library 3.6.0    base
# survival   survival   /usr/lib64/R/library 2.44-1.1 recommended
# tcltk      tcltk      /usr/lib64/R/library 3.6.0    base
# tools      tools      /usr/lib64/R/library 3.6.0    base
# utf8       utf8       /usr/lib64/R/library 1.1.4    NA
# utils      utils      /usr/lib64/R/library 3.6.0    base
# uuid       uuid       /usr/lib64/R/library 0.1-2    NA
# vctrs      vctrs      /usr/lib64/R/library 0.2.0    NA
# zeallot    zeallot    /usr/lib64/R/library 0.1.0    NA
#            Depends
# assertthat NA
# backports  R (>= 3.0.0)
# base       NA
# base64enc  R (>= 2.9.0)
# boot       R (>= 3.0.0), graphics, stats
# class      R (>= 3.0.0), stats, utils
# cli        R (>= 2.10)
# cluster    R (>= 3.3.0)
# codetools  R (>= 2.1)
# compiler   NA
# crayon     NA
# datasets   NA
# digest     R (>= 3.1.0)
# ellipsis   R (>= 3.1)
# evaluate   R (>= 3.0.2)
# fansi      R (>= 3.1.0)
# foreign    R (>= 3.0.0)
# glue       R (>= 3.1)
# graphics   NA
# grDevices  NA
# grid       NA
# htmltools  R (>= 2.14.1)
# IRdisplay  R (>= 3.0.1)
# IRkernel   R (>= 3.2.0)
# jsonlite   methods
# KernSmooth R (>= 2.5.0), stats
# lattice    R (>= 3.0.0)
# MASS       R (>= 3.1.0), grDevices, graphics, stats, utils
# Matrix     R (>= 3.2.0)
# methods    NA
# mgcv       R (>= 2.14.0), nlme (>= 3.1-64)
# nlme       R (>= 3.4.0)
# nnet       R (>= 2.14.0), stats, utils
# parallel   NA
# pbdZMQ     R (>= 3.2.0)
# pillar     NA
# Rcpp       R (>= 3.0.0)
# repr       R (>= 3.0.1)
# rlang      R (>= 3.2.0)
# rpart      R (>= 2.15.0), graphics, stats, grDevices
# spatial    R (>= 3.0.0), graphics, stats, utils
# splines    NA
# stats      NA
# stats4     NA
# survival   R (>= 2.13.0)
# tcltk      NA
# tools      NA
# utf8       R (>= 2.10)
# utils      NA
# uuid       R (>= 2.9.0)
# vctrs      R (>= 3.2)
# zeallot    NA
#            Imports
# assertthat tools
# backports  utils
# base       NA
# base64enc  NA
# boot       NA
# class      MASS
# cli        assertthat, crayon (>= 1.3.4), methods, utils
# cluster    graphics, grDevices, stats, utils
# codetools  NA
# compiler   NA
# crayon     grDevices, methods, utils
# datasets   NA
# digest     NA
# ellipsis   rlang (>= 0.3.0)
# evaluate   methods
# fansi      NA
# foreign    methods, utils, stats
# glue       methods
# graphics   grDevices
# grDevices  NA
# grid       grDevices, utils
# htmltools  utils, digest, Rcpp
# IRdisplay  methods, repr
# IRkernel   repr (>= 0.4.99), methods, evaluate (>= 0.10), IRdisplay (>=\n0.3.0.9999), pbdZMQ (>= 0.2-1), crayon, jsonlite (>= 0.9.6),\nuuid, digest
# jsonlite   NA
# KernSmooth NA
# lattice    grid, grDevices, graphics, stats, utils
# MASS       methods
# Matrix     methods, graphics, grid, stats, utils, lattice
# methods    utils, stats
# mgcv       methods, stats, graphics, Matrix, splines, utils
# nlme       graphics, stats, utils, lattice
# nnet       NA
# parallel   tools, compiler
# pbdZMQ     NA
# pillar     cli, crayon (>= 1.3.4), fansi, rlang (>= 0.3.0), utf8 (>=\n1.1.0), vctrs
# Rcpp       methods, utils
# repr       utils, grDevices, htmltools, jsonlite, pillar (>= 1.4.0),\nbase64enc
# rlang      NA
# rpart      NA
# spatial    NA
# splines    graphics, stats
# stats      utils, grDevices, graphics
# stats4     graphics, methods, stats
# survival   graphics, Matrix, methods, splines, stats, utils
# tcltk      utils
# tools      NA
# utf8       NA
# utils      NA
# uuid       NA
# vctrs      backports, ellipsis (>= 0.2.0), digest, glue, rlang (>=\n0.4.0), zeallot
# zeallot    NA
#            LinkingTo
# assertthat NA
# backports  NA
# base       NA
# base64enc  NA
# boot       NA
# class      NA
# cli        NA
# cluster    NA
# codetools  NA
# compiler   NA
# crayon     NA
# datasets   NA
# digest     NA
# ellipsis   NA
# evaluate   NA
# fansi      NA
# foreign    NA
# glue       NA
# graphics   NA
# grDevices  NA
# grid       NA
# htmltools  Rcpp
# IRdisplay  NA
# IRkernel   NA
# jsonlite   NA
# KernSmooth NA
# lattice    NA
# MASS       NA
# Matrix     NA
# methods    NA
# mgcv       NA
# nlme       NA
# nnet       NA
# parallel   NA
# pbdZMQ     NA
# pillar     NA
# Rcpp       NA
# repr       NA
# rlang      NA
# rpart      NA
# spatial    NA
# splines    NA
# stats      NA
# stats4     NA
# survival   NA
# tcltk      NA
# tools      NA
# utf8       NA
# utils      NA
# uuid       NA
# vctrs      NA
# zeallot    NA
#            Suggests
# assertthat testthat, covr
# backports  NA
# base       methods
# base64enc  NA
# boot       MASS, survival
# class      NA
# cli        covr, fansi, mockery, testthat, webshot, withr
# cluster    MASS, Matrix
# codetools  NA
# compiler   NA
# crayon     mockery, rstudioapi, testthat, withr
# datasets   NA
# digest     tinytest, knitr, rmarkdown
# ellipsis   covr, testthat
# evaluate   testthat, lattice, ggplot2
# fansi      unitizer, knitr, rmarkdown
# foreign    NA
# glue       testthat, covr, magrittr, crayon, knitr, rmarkdown, DBI,\nRSQLite, R.utils, forcats, microbenchmark, rprintf, stringr,\nggplot2, dplyr, withr
# graphics   NA
# grDevices  KernSmooth
# grid       lattice
# htmltools  markdown, testthat
# IRdisplay  testthat, withr
# IRkernel   testthat, roxygen2
# jsonlite   httr, curl, plyr, testthat, knitr, rmarkdown, R.rsp, sp
# KernSmooth MASS
# lattice    KernSmooth, MASS, latticeExtra
# MASS       lattice, nlme, nnet, survival
# Matrix     expm, MASS
# methods    codetools
# mgcv       parallel, survival, MASS
# nlme       Hmisc, MASS
# nnet       MASS
# parallel   methods
# pbdZMQ     NA
# pillar     knitr, lubridate, testthat, withr
# Rcpp       RUnit, inline, rbenchmark, knitr, rmarkdown, pinp, pkgKitten\n(>= 0.1.2)
# repr       methods, highr, Cairo, stringr, testthat, diffobj (>= 0.2.3),\nleaflet
# rlang      covr, crayon, magrittr, methods, pillar, rmarkdown, testthat\n(>= 2.0.0)
# rpart      survival
# spatial    MASS
# splines    Matrix, methods
# stats      MASS, Matrix, SuppDists, methods, stats4
# stats4     NA
# survival   NA
# tcltk      NA
# tools      codetools, methods, xml2, curl, commonmark
# utf8       knitr, rmarkdown, testthat
# utils      methods, xml2, commonmark
# uuid       NA
# vctrs      bit64, covr, crayon, generics, knitr, pillar (>= 1.4.1),\npkgdown, rmarkdown, testthat, tibble
# zeallot    testthat, knitr, rmarkdown, purrr, magrittr
#            Enhances
# assertthat NA
# backports  NA
# base       NA
# base64enc  png
# boot       NA
# class      NA
# cli        NA
# cluster    NA
# codetools  NA
# compiler   NA
# crayon     NA
# datasets   NA
# digest     NA
# ellipsis   NA
# evaluate   NA
# fansi      NA
# foreign    NA
# glue       NA
# graphics   NA
# grDevices  NA
# grid       NA
# htmltools  knitr
# IRdisplay  NA
# IRkernel   NA
# jsonlite   NA
# KernSmooth NA
# lattice    chron
# MASS       NA
# Matrix     MatrixModels, graph, SparseM, sfsmisc
# methods    NA
# mgcv       NA
# nlme       NA
# nnet       NA
# parallel   snow, nws, Rmpi
# pbdZMQ     NA
# pillar     NA
# Rcpp       NA
# repr       data.table, dplyr, htmlwidgets, vegalite, plotly, geojsonio
# rlang      NA
# rpart      NA
# spatial    NA
# splines    NA
# stats      NA
# stats4     NA
# survival   NA
# tcltk      NA
# tools      NA
# utf8       NA
# utils      NA
# uuid       NA
# vctrs      NA
# zeallot    NA
#            License                                License_is_FOSS
# assertthat GPL-3                                  NA
# backports  GPL-2                                  NA
# base       Part of R 3.6.0                        NA
# base64enc  GPL-2 | GPL-3                          NA
# boot       Unlimited                              NA
# class      GPL-2 | GPL-3                          NA
# cli        MIT + file LICENSE                     NA
# cluster    GPL (>= 2)                             NA
# codetools  GPL                                    NA
# compiler   Part of R 3.6.0                        NA
# crayon     MIT + file LICENSE                     NA
# datasets   Part of R 3.6.0                        NA
# digest     GPL (>= 2)                             NA
# ellipsis   GPL-3                                  NA
# evaluate   MIT + file LICENSE                     NA
# fansi      GPL (>= 2)                             NA
# foreign    GPL (>= 2)                             NA
# glue       MIT + file LICENSE                     NA
# graphics   Part of R 3.6.0                        NA
# grDevices  Part of R 3.6.0                        NA
# grid       Part of R 3.6.0                        NA
# htmltools  GPL (>= 2)                             NA
# IRdisplay  MIT + file LICENSE                     NA
# IRkernel   MIT + file LICENSE                     NA
# jsonlite   MIT + file LICENSE                     NA
# KernSmooth Unlimited                              NA
# lattice    GPL (>= 2)                             NA
# MASS       GPL-2 | GPL-3                          NA
# Matrix     GPL (>= 2) | file LICENCE              NA
# methods    Part of R 3.6.0                        NA
# mgcv       GPL (>= 2)                             NA
# nlme       GPL (>= 2) | file LICENCE              NA
# nnet       GPL-2 | GPL-3                          NA
# parallel   Part of R 3.6.0                        NA
# pbdZMQ     GPL-3                                  NA
# pillar     GPL-3                                  NA
# Rcpp       GPL (>= 2)                             NA
# repr       GPL-3                                  NA
# rlang      GPL-3                                  NA
# rpart      GPL-2 | GPL-3                          NA
# spatial    GPL-2 | GPL-3                          NA
# splines    Part of R 3.6.0                        NA
# stats      Part of R 3.6.0                        NA
# stats4     Part of R 3.6.0                        NA
# survival   LGPL (>= 2)                            NA
# tcltk      Part of R 3.6.0                        NA
# tools      Part of R 3.6.0                        NA
# utf8       Apache License (== 2.0) | file LICENSE NA
# utils      Part of R 3.6.0                        NA
# uuid       MIT + file LICENSE                     NA
# vctrs      GPL-3                                  NA
# zeallot    MIT + file LICENSE                     NA
#            License_restricts_use OS_type MD5sum NeedsCompilation Built
# assertthat NA                    NA      NA     no               3.6.0
# backports  NA                    NA      NA     yes              3.6.0
# base       NA                    NA      NA     NA               3.6.0
# base64enc  NA                    NA      NA     yes              3.6.0
# boot       NA                    NA      NA     no               3.6.0
# class      NA                    NA      NA     yes              3.6.0
# cli        NA                    NA      NA     no               3.6.0
# cluster    NA                    NA      NA     yes              3.6.0
# codetools  NA                    NA      NA     no               3.6.0
# compiler   NA                    NA      NA     NA               3.6.0
# crayon     NA                    NA      NA     no               3.6.0
# datasets   NA                    NA      NA     NA               3.6.0
# digest     NA                    NA      NA     yes              3.6.0
# ellipsis   NA                    NA      NA     yes              3.6.0
# evaluate   NA                    NA      NA     no               3.6.0
# fansi      NA                    NA      NA     yes              3.6.0
# foreign    NA                    NA      NA     yes              3.6.0
# glue       NA                    NA      NA     yes              3.6.0
# graphics   NA                    NA      NA     yes              3.6.0
# grDevices  NA                    NA      NA     yes              3.6.0
# grid       NA                    NA      NA     yes              3.6.0
# htmltools  NA                    NA      NA     yes              3.6.0
# IRdisplay  NA                    NA      NA     no               3.6.0
# IRkernel   NA                    NA      NA     no               3.6.0
# jsonlite   NA                    NA      NA     yes              3.6.0
# KernSmooth NA                    NA      NA     yes              3.6.0
# lattice    NA                    NA      NA     yes              3.6.0
# MASS       NA                    NA      NA     yes              3.6.0
# Matrix     NA                    NA      NA     yes              3.6.0
# methods    NA                    NA      NA     yes              3.6.0
# mgcv       NA                    NA      NA     yes              3.6.0
# nlme       NA                    NA      NA     yes              3.6.0
# nnet       NA                    NA      NA     yes              3.6.0
# parallel   NA                    NA      NA     yes              3.6.0
# pbdZMQ     NA                    NA      NA     yes              3.6.0
# pillar     NA                    NA      NA     no               3.6.0
# Rcpp       NA                    NA      NA     yes              3.6.0
# repr       NA                    NA      NA     no               3.6.0
# rlang      NA                    NA      NA     yes              3.6.0
# rpart      NA                    NA      NA     yes              3.6.0
# spatial    NA                    NA      NA     yes              3.6.0
# splines    NA                    NA      NA     yes              3.6.0
# stats      NA                    NA      NA     yes              3.6.0
# stats4     NA                    NA      NA     NA               3.6.0
# survival   NA                    NA      NA     yes              3.6.0
# tcltk      NA                    NA      NA     yes              3.6.0
# tools      NA                    NA      NA     yes              3.6.0
# utf8       NA                    NA      NA     yes              3.6.0
# utils      NA                    NA      NA     yes              3.6.0
# uuid       NA                    NA      NA     yes              3.6.0
# vctrs      NA                    NA      NA     yes              3.6.0
# zeallot    NA                    NA      NA     no               3.6.0

# %%
R.home()
# Out:
# [1] "/usr/lib64/R"

# %%
library(glmnet)
# Out:
# Error in library(glmnet): there is no package called ‘glmnet’
# Traceback:
#
# 1. library(glmnet)

# %%
ENet_fit <- cv.glmnet(x=train[complete.cases(train),], y= train_labels[complete.cases(train)], family = "binomial", type.measure = "auc", alpha = 0.5) #alpha: mixing term, lasso, 1-alpha ridge.
